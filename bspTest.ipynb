# %%
bspfilename = "bsptest.bsp"
def from_str(ar):
    return ar.decode('ascii')

class t_char():
    def __init__(self):
        self.s=1
    def l(self,ar,o):
        self.ar=ar
        self.o=o
        self.b=ar[o:o+self.s]
        self.v = self.cvt()
    def cvt(self):     
        return int.from_bytes(self.b,"little")
    
class t_int():
    def __init__(self):
        self.s=4
    def l(self,ar,o):
        self.ar=ar
        self.o=o
        self.b=ar[o:o+self.s]
        self.v=self.cvt()
    def cvt(self):     
        return int.from_bytes(self.b,"little")
    
class array():
    def __init__(self):
        pass
    def l(self, ar, o, nm_el, t_el):
        self.ar=ar
        self.o=o
        self.t_el=t_el
        self.s_el=t_el().s
        self.nm_el=nm_el
        self.s=self.s_el * self.nm_el
        self.b=ar[o:o+self.s]
        self.v=self.cvt()
    def cvt(self):
        array_contents=[self.t_el() for i in range(0,self.nm_el)
        for el in array_contents:
            el
        return [self.t_el().l(self.ar,(self.o + (i*self.s_el))) for i in range(0,self.nm_el)]

class t_lump():
    def __init__(self):
        self.s = 16
    def l(self,ar,o):
        self.ar=ar
        self.o=o
        self.t_o=t_int()
        self.t_o.l(ar,o)
        self.t_s=t_int()
        self.t_s.l(ar,o+4)
        self.t_vsn=t_int()
        self.t_vsn.l(ar,o+8)
        self.id=array()
        self.id.l(ar,o+12,4,t_char)
    
class t_header():
    def __init__(self):
        self.s=4+4+(64*t_lump().s)+4
    def l(self,ar,o):
        self.id=t_int()
        self.id.l(ar,o)
        self.vsn=t_int()
        self.vsn.l(ar,o+4)
        self.lumps=array()
        self.lumps.l(ar,o+8,64,t_lump)
        self.rev=t_int()
        self.rev.l(ar,o+self.lumps.s)        
        

class bsp():
    def __init__(self,bspname):
        self.bsp={}
        self.ar=self.readBSP(bspname)
        self.convertBSP()
    def readBSP(self,bspfile):
        with open(bspfile,"rb") as bf:
            filecontents=bf.read(-1)
        return filecontents
    def convertBSP(self):
        self.header=t_header()
        self.header.l(self.ar,0)

# %%
tbsp=bsp(bspfilename)
tbsp.header.lumps.v
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
test=[1,2,3,4,5,6,7,8]
def a(ar):
    return ar[3:]
print(test)
ar=a(test)
print(ar)
ar[4]=10
print(test)
print(ar)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# [4, 5, 6, 7, 8]
# [1, 2, 3, 4, 5, 6, 7, 8]
# [4, 5, 6, 7, 10]
